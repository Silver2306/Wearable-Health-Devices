# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/wearable_health_devices.csv")
df.head()
# Out:
#   user_id        date  age  gender              region device_model  \
# 0   U0001  2025-05-11   35  female  TR-EasternAnatolia   FitPulse X
# 1   U0001  2025-05-12   35  female  TR-EasternAnatolia   FitPulse X
# 2   U0001  2025-05-13   35  female  TR-EasternAnatolia   FitPulse X
# 3   U0001  2025-05-14   35  female  TR-EasternAnatolia   FitPulse X
# 4   U0001  2025-05-15   35  female  TR-EasternAnatolia   FitPulse X
#
#    height_cm  weight_kg   bmi  resting_hr_bpm  ...  sleep_duration_hours  \
# 0        170       58.7  20.3       71.481219  ...              6.846974
# 1        170       58.7  20.3       67.964498  ...              7.103551
# 2        170       58.7  20.3       66.760038  ...              7.954798
# 3        170       58.7  20.3       65.008374  ...              7.375435
# 4        170       58.7  20.3       67.528909  ...              7.569236
#
#    sleep_efficiency  sleep_latency_min  wake_after_sleep_onset_min  \
# 0          0.915716               14.0                        39.0
# 1          0.944442               25.0                        38.0
# 2          0.859938               19.0                        32.0
# 3          0.970183               12.0                        40.0
# 4          0.916390                8.0                        23.0
#
#    sleep_stage_rem_pct  sleep_stage_deep_pct  sleep_stage_light_pct  \
# 0                0.289                 0.144                  0.567
# 1                0.209                 0.204                  0.588
# 2                0.203                 0.189                  0.608
# 3                0.211                 0.159                  0.630
# 4                0.236                 0.206                  0.558
#
#    stress_score mindfulness_minutes      mood
# 0            55                   3       bad
# 1            58                   0  very_bad
# 2            50                   8      good
# 3            54                  12   neutral
# 4            55                   0   neutral
#
# [5 rows x 33 columns]

# %%
df.columns.tolist()
# Out:
# ['user_id',
#  'date',
#  'age',
#  'gender',
#  'region',
#  'device_model',
#  'height_cm',
#  'weight_kg',
#  'bmi',
#  'resting_hr_bpm',
#  'avg_hr_day_bpm',
#  'hrv_rmssd_ms',
#  'spo2_avg_pct',
#  'sbp_mmHg',
#  'dbp_mmHg',
#  'steps',
#  'distance_km',
#  'calories_kcal',
#  'workout_type',
#  'workout_minutes',
#  'caffeine_mg',
#  'alcohol_units',
#  'screen_time_min',
#  'sleep_duration_hours',
#  'sleep_efficiency',
#  'sleep_latency_min',
#  'wake_after_sleep_onset_min',
#  'sleep_stage_rem_pct',
#  'sleep_stage_deep_pct',
#  'sleep_stage_light_pct',
#  'stress_score',
#  'mindfulness_minutes',
#  'mood']

# %%
df.shape
# Out:
# (55200, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55200 entries, 0 to 55199
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     55200 non-null  object
#  1   date                        55200 non-null  object
#  2   age                         55200 non-null  int64
#  3   gender                      55200 non-null  object
#  4   region                      55200 non-null  object
#  5   device_model                55200 non-null  object
#  6   height_cm                   55200 non-null  int64
#  7   weight_kg                   55200 non-null  float64
#  8   bmi                         55200 non-null  float64
#  9   resting_hr_bpm              55200 non-null  float64
#  10  avg_hr_day_bpm              54143 non-null  float64
#  11  hrv_rmssd_ms                54143 non-null  float64
#  12  spo2_avg_pct                55200 non-null  float64
#  13  sbp_mmHg                    55200 non-null  float64
#  14  dbp_mmHg                    55200 non-null  float64
#  15  steps                       54143 non-null  float64
#  16  distance_km                 54143 non-null  float64
#  17  calories_kcal               54143 non-null  float64
#  18  workout_type                55200 non-null  object
#  19  workout_minutes             55200 non-null  int64
#  20  caffeine_mg                 55200 non-null  float64
#  21  alcohol_units               55200 non-null  float64
#  22  screen_time_min             55200 non-null  float64
#  23  sleep_duration_hours        54143 non-null  float64
#  24  sleep_efficiency            54143 non-null  float64
#  25  sleep_latency_min           54143 non-null  float64
#  26  wake_after_sleep_onset_min  54143 non-null  float64
#  27  sleep_stage_rem_pct         54143 non-null  float64
#  28  sleep_stage_deep_pct        54143 non-null  float64
#  29  sleep_stage_light_pct       54143 non-null  float64
#  30  stress_score                55200 non-null  int64
#  31  mindfulness_minutes         55200 non-null  int64
#  32  mood                        55200 non-null  object
# dtypes: float64(21), int64(5), object(7)
# memory usage: 13.9+ MB

# %%
df.isnull().sum()
# Out:
# user_id                          0
# date                             0
# age                              0
# gender                           0
# region                           0
# device_model                     0
# height_cm                        0
# weight_kg                        0
# bmi                              0
# resting_hr_bpm                   0
# avg_hr_day_bpm                1057
# hrv_rmssd_ms                  1057
# spo2_avg_pct                     0
# sbp_mmHg                         0
# dbp_mmHg                         0
# steps                         1057
# distance_km                   1057
# calories_kcal                 1057
# workout_type                     0
# workout_minutes                  0
# caffeine_mg                      0
# alcohol_units                    0
# screen_time_min                  0
# sleep_duration_hours          1057
# sleep_efficiency              1057
# sleep_latency_min             1057
# wake_after_sleep_onset_min    1057
# sleep_stage_rem_pct           1057
# sleep_stage_deep_pct          1057
# sleep_stage_light_pct         1057
# stress_score                     0
# mindfulness_minutes              0
# mood                             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# user_id                         300
# date                            184
# age                              35
# gender                            3
# region                            7
# device_model                      5
# height_cm                        45
# weight_kg                       213
# bmi                             145
# resting_hr_bpm                55076
# avg_hr_day_bpm                54108
# hrv_rmssd_ms                  53162
# spo2_avg_pct                  55005
# sbp_mmHg                      54567
# dbp_mmHg                      54995
# steps                         16059
# distance_km                    1899
# calories_kcal                  1604
# workout_type                      7
# workout_minutes                  93
# caffeine_mg                   52075
# alcohol_units                 43100
# screen_time_min               54450
# sleep_duration_hours          54143
# sleep_efficiency              43763
# sleep_latency_min                51
# wake_after_sleep_onset_min       82
# sleep_stage_rem_pct             326
# sleep_stage_deep_pct            359
# sleep_stage_light_pct           514
# stress_score                     80
# mindfulness_minutes              34
# mood                              5
# dtype: int64

# %%
df.describe(include="all")
# Out:
#        user_id        date           age  gender     region  device_model  \
# count    55200       55200  55200.000000   55200      55200         55200
# unique     300         184           NaN       3          7             5
# top      U0001  2025-05-11           NaN  female  TR-Aegean  SleepSense 2
# freq       184         300           NaN   27600       9752         12696
# mean       NaN         NaN     31.513333     NaN        NaN           NaN
# std        NaN         NaN      7.602031     NaN        NaN           NaN
# min        NaN         NaN     18.000000     NaN        NaN           NaN
# 25%        NaN         NaN     26.000000     NaN        NaN           NaN
# 50%        NaN         NaN     31.000000     NaN        NaN           NaN
# 75%        NaN         NaN     37.000000     NaN        NaN           NaN
# max        NaN         NaN     57.000000     NaN        NaN           NaN
#
#            height_cm     weight_kg           bmi  resting_hr_bpm  ...  \
# count   55200.000000  55200.000000  55200.000000    55200.000000  ...
# unique           NaN           NaN           NaN             NaN  ...
# top              NaN           NaN           NaN             NaN  ...
# freq             NaN           NaN           NaN             NaN  ...
# mean      172.293333     72.285333     24.524333       64.530222  ...
# std         9.474646     11.770416      4.622787        8.179800  ...
# min       150.000000     45.000000     14.100000       42.000000  ...
# 25%       165.000000     64.350000     20.875000       58.968564  ...
# 50%       172.000000     72.650000     24.400000       64.293327  ...
# 75%       178.250000     79.450000     27.400000       70.010714  ...
# max       200.000000    100.800000     37.900000       94.119526  ...
#
#         sleep_duration_hours  sleep_efficiency  sleep_latency_min  \
# count           54143.000000      54143.000000       54143.000000
# unique                   NaN               NaN                NaN
# top                      NaN               NaN                NaN
# freq                     NaN               NaN                NaN
# mean                6.990294          0.880257          19.494598
# std                 0.841838          0.089117           8.298141
# min                 3.500000          0.600000           2.000000
# 25%                 6.420908          0.815451          14.000000
# 50%                 6.987131          0.886133          19.000000
# 75%                 7.559351          0.965269          25.000000
# max                10.500000          0.990000          55.000000
#
#         wake_after_sleep_onset_min  sleep_stage_rem_pct  sleep_stage_deep_pct  \
# count                 54143.000000         54143.000000          54143.000000
# unique                         NaN                  NaN                   NaN
# top                            NaN                  NaN                   NaN
# freq                           NaN                  NaN                   NaN
# mean                     36.927285             0.233261              0.203943
# std                      10.663089             0.045247              0.068080
# min                       0.000000             0.055000              0.050000
# 25%                      30.000000             0.203000              0.156000
# 50%                      37.000000             0.233000              0.201000
# 75%                      44.000000             0.264000              0.249500
# max                      81.000000             0.410000              0.413000
#
#         sleep_stage_light_pct  stress_score mindfulness_minutes   mood
# count            54143.000000  55200.000000        55200.000000  55200
# unique                    NaN           NaN                 NaN      5
# top                       NaN           NaN                 NaN    bad
# freq                      NaN           NaN                 NaN  20773
# mean                 0.562797     67.035163            9.000018    NaN
# std                  0.080598     11.751781            5.674420    NaN
# min                  0.304000     19.000000            0.000000    NaN
# 25%                  0.509000     59.000000            5.000000    NaN
# 50%                  0.564000     67.000000            9.000000    NaN
# 75%                  0.619000     75.000000           13.000000    NaN
# max                  0.869000    100.000000           33.000000    NaN
#
# [11 rows x 33 columns]

# %%
df["date"].min(), df["date"].max()
# Out:
# ('2025-05-11', '2025-11-10')

# %%
df["user_id"].value_counts().describe()
# Out:
# count    300.0
# mean     184.0
# std        0.0
# min      184.0
# 25%      184.0
# 50%      184.0
# 75%      184.0
# max      184.0
# Name: count, dtype: float64
